# %% [markdown]
# # Chapter 18 Companion Notebook
# **Build Your First LLM — Chapter 18: What's Next**
#
# This notebook is different from the others. It's less about running code and more about reflection and planning.
#
# - Purpose: Celebrate your journey, plan your next steps
# - Data: No external files needed
# - Runtime: CPU is fine (minimal code)

# %% [markdown]
# ## What You Built
#
# Let's take a moment to appreciate how far you've come.

# %%
# Run this to see your journey
journey = [
    ("Part I", "Understanding", "You learned HOW LLMs work: embeddings, attention, Transformers"),
    ("Part II", "Building", "You gained practical skills: Python, tensors, training loops"),
    ("Part III", "Training", "You built an LLM FROM SCRATCH and trained it on real data"),
    ("Part IV", "Creating", "You made it useful: fine-tuning, RAG, tool use"),
    ("Part V", "Deploying", "You shipped it: APIs, cloud deployment, GPU acceleration"),
]

print("="*60)
print("YOUR LLM JOURNEY")
print("="*60)
for part, stage, description in journey:
    print(f"\n{part}: {stage}")
    print(f"   {description}")
print("\n" + "="*60)
print("You didn't just read about AI. You BUILT it.")
print("="*60)

# %% [markdown]
# ## Skills Checklist
#
# How many of these can you confidently do? Be honest with yourself.

# %%
# Mark True for skills you're confident about
theory_skills = {
    "Explain how embeddings represent words as vectors": False,
    "Describe the attention mechanism and why it matters": False,
    "Sketch the Transformer architecture on a whiteboard": False,
    "Explain why models hallucinate": False,
}

building_skills = {
    "Prepare and clean training data": False,
    "Build and train a neural network from scratch": False,
    "Fine-tune a pretrained model on custom data": False,
    "Implement RAG for external knowledge": False,
    "Add tool use to an LLM application": False,
}

production_skills = {
    "Build a FastAPI server for model inference": False,
    "Implement input validation and error handling": False,
    "Set up structured logging": False,
    "Deploy to the cloud with GPU support": False,
    "Manage secrets and costs": False,
}

# Calculate totals
all_skills = {**theory_skills, **building_skills, **production_skills}
total = len(all_skills)
checked = sum(1 for v in all_skills.values() if v)

print(f"Skills checked: {checked}/{total}")
print(f"\nUpdate the 'False' values to 'True' for skills you're confident about.")
print(f"If you followed the book exercises, most should be True!")

# %% [markdown]
# ## Three Paths Forward
#
# Which direction interests you most?

# %%
paths = {
    "Deeper Technical (ML Research)": {
        "for_you_if": "You want to understand WHY models work",
        "example_project": "Build a model that explains its reasoning step-by-step",
        "learn_next": ["Better evaluation", "Architecture variants", "Interpretability"],
    },
    "Product & Applications (Builder)": {
        "for_you_if": "You want to CREATE useful things",
        "example_project": "Chatbot that searches notes and schedules calendar events",
        "learn_next": ["Structured outputs", "Better retrieval", "User experience"],
    },
    "Production & Infrastructure (Systems)": {
        "for_you_if": "You want things to WORK reliably at scale",
        "example_project": "Deploy model for 100 users with cost tracking",
        "learn_next": ["Cost optimization", "Monitoring", "LLMOps"],
    },
}

for path_name, details in paths.items():
    print(f"\n{'='*50}")
    print(f"PATH: {path_name}")
    print(f"{'='*50}")
    print(f"For you if: {details['for_you_if']}")
    print(f"Example project: {details['example_project']}")
    print(f"Learn next: {', '.join(details['learn_next'])}")

# %% [markdown]
# ## Capstone Projects
#
# Pick one to start this week!

# %%
capstones = [
    {
        "name": "Production-Ready RAG System",
        "time": "2-3 weekends",
        "difficulty": "Medium",
        "what_you_build": "Search system over your documents with citations",
        "success_metric": "Users get accurate answers with source links",
        "chapters_to_revisit": ["Ch14 (RAG)", "Ch16 (API)", "Ch17 (deployment)"],
    },
    {
        "name": "Fine-Tuned Domain Assistant",
        "time": "3-4 weekends",
        "difficulty": "Medium-Hard",
        "what_you_build": "Model specialized for one domain",
        "success_metric": "Beats generic model on domain-specific questions",
        "chapters_to_revisit": ["Ch7 (data)", "Ch13 (fine-tuning)", "Ch6 (eval)"],
    },
    {
        "name": "Single-Tool Agent",
        "time": "2 weekends",
        "difficulty": "Medium",
        "what_you_build": "Model that uses ONE tool reliably",
        "success_metric": "95% correct tool calls on test set",
        "chapters_to_revisit": ["Ch15 (tools)", "Ch16 (validation)"],
    },
]

for i, cap in enumerate(capstones, 1):
    print(f"\n{'='*50}")
    print(f"CAPSTONE {i}: {cap['name']}")
    print(f"{'='*50}")
    print(f"Time: {cap['time']}")
    print(f"Difficulty: {cap['difficulty']}")
    print(f"You build: {cap['what_you_build']}")
    print(f"Success: {cap['success_metric']}")
    print(f"Revisit: {', '.join(cap['chapters_to_revisit'])}")

# %% [markdown]
# ## Resources by Comfort Level

# %%
resources = {
    "Gentle Next Steps (Start Here)": [
        ("Hugging Face NLP Course", "https://huggingface.co/learn/nlp-course"),
        ("r/LocalLLaMA", "https://reddit.com/r/LocalLLaMA"),
        ("Anthropic Prompt Guide", "https://docs.anthropic.com/claude/docs/prompt-engineering"),
    ],
    "When You Feel Confident": [
        ("Stanford CS324", "https://stanford-cs324.github.io/winter2022/"),
        ("Attention Is All You Need (paper)", "https://arxiv.org/abs/1706.03762"),
        ("DeepLearning.AI Short Courses", "https://www.deeplearning.ai/short-courses/"),
    ],
    "Join the Community": [
        ("Hugging Face Discord", "https://huggingface.co/join/discord"),
        ("MLOps Community Slack", "https://mlops.community/"),
        ("Contribute to transformers", "https://github.com/huggingface/transformers"),
    ],
}

for category, links in resources.items():
    print(f"\n{category}:")
    print("-" * len(category))
    for name, url in links:
        print(f"  • {name}")
        print(f"    {url}")

# %% [markdown]
# ## Your Next Steps Planner
#
# Fill this out to create your personal learning plan:

# %%
# YOUR PERSONAL NEXT STEPS
# Edit these values!

my_plan = {
    "path_i_chose": "Builder",  # "ML Research", "Builder", or "Systems"
    "capstone_to_start": "Production-Ready RAG System",
    "first_resource": "Hugging Face NLP Course",
    "community_to_join": "r/LocalLLaMA",
    "start_date": "This weekend",
}

print("="*50)
print("MY LEARNING PLAN")
print("="*50)
print(f"\nPath: {my_plan['path_i_chose']}")
print(f"First Project: {my_plan['capstone_to_start']}")
print(f"Learning Resource: {my_plan['first_resource']}")
print(f"Community: {my_plan['community_to_join']}")
print(f"Starting: {my_plan['start_date']}")
print("\n" + "="*50)
print("Now go build something!")
print("="*50)

# %% [markdown]
# ## Capstone 1 Starter: RAG System
#
# If you chose the RAG capstone, here's a skeleton to get you started:

# %%
# RAG System Starter Template
rag_template = '''
# Production-Ready RAG System
# Expand this based on what you learned in Ch14-17

from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI(title="My RAG API")

class Query(BaseModel):
    question: str
    top_k: int = 3

class Answer(BaseModel):
    response: str
    sources: list[str]  # Citations!

# TODO: Load your document embeddings (Ch14)
# embeddings = load_embeddings("my_corpus.jsonl")

@app.post("/ask", response_model=Answer)
def ask(query: Query):
    # TODO: Retrieve relevant documents (Ch14)
    # docs = retrieve(query.question, top_k=query.top_k)
    
    # TODO: Generate answer with context (Ch14)
    # answer = generate_with_context(query.question, docs)
    
    # TODO: Extract source citations
    # sources = [doc.source_url for doc in docs]
    
    return Answer(
        response="Implement this based on Ch14!",
        sources=["source1.txt", "source2.txt"]
    )

# Deploy with: modal deploy my_rag.py (Ch17)
'''

print("RAG System Starter Template:")
print(rag_template)

# %% [markdown]
# ## Capstone 3 Starter: Single-Tool Agent
#
# If you chose the agent capstone, here's a skeleton:

# %%
# Single-Tool Agent Starter Template
agent_template = '''
# Single-Tool Agent
# Start simple: ONE tool only!

import json

# Define your ONE tool
def calculator(expression: str) -> str:
    """Evaluate a math expression."""
    try:
        # WARNING: eval is dangerous! Use a proper math parser in production
        result = eval(expression, {"__builtins__": {}}, {})
        return str(result)
    except:
        return "Error: Could not calculate"

TOOL_SCHEMA = {
    "name": "calculator",
    "description": "Evaluate a math expression",
    "parameters": {
        "expression": "A math expression like \'2 + 2\' or \'15 * 7\'"
    }
}

def should_use_tool(user_message: str) -> bool:
    """Decide if we need the calculator."""
    # TODO: Use LLM to classify (Ch15)
    math_keywords = ["calculate", "compute", "what is", "+", "-", "*", "/"]
    return any(kw in user_message.lower() for kw in math_keywords)

def extract_expression(user_message: str) -> str:
    """Extract the math expression from the message."""
    # TODO: Use LLM to extract (Ch15)
    return user_message  # Placeholder

def agent(user_message: str) -> str:
    """Process user message, potentially using tools."""
    if should_use_tool(user_message):
        expression = extract_expression(user_message)
        result = calculator(expression)
        return f"The answer is: {result}"
    else:
        return "I can help with calculations. Try asking me to calculate something!"

# Test it
print(agent("What is 15 * 7?"))
'''

print("Single-Tool Agent Starter Template:")
print(agent_template)

# %% [markdown]
# ## Final Reflection
#
# In Chapter 1, you asked: *How does this thing actually work?*
#
# Now you can answer that question. Not because someone told you, but because you built one yourself.
#
# **You're not just learning about AI. You're building it.**
#
# Keep going.

# %%
print("\n" + "="*60)
print("CONGRATULATIONS!")
print("="*60)
print("""
You've completed "Build Your First LLM"

You now have:
  ✓ Deep understanding of how LLMs work
  ✓ Practical skills to build and train models
  ✓ Production engineering capabilities
  ✓ A deployed model accessible to anyone

What comes next is up to you.

Pick a project. Join a community. Keep building.
""")
print("="*60)
